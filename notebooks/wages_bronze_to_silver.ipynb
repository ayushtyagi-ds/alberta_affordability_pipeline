# %% [markdown]
# #This notebook reads  the wages data from Bronze table, cleans it, and saves it to Silver table.

# %%
# %sql
DROP TABLE IF EXISTS mycatalog.default.wages_bronze;
DROP TABLE IF EXISTS mycatalog.default.avergae_weekly_earning;

# %%
# 1. Define the path to your raw file in DBFS
# This is the original file we uploaded
file_path = "/FileStore/tables/Avergae_weekly_earning.csv" 

# 2. Define how many junk rows to skip
rows_to_skip = 53 

print(f"Reading raw file from: {file_path}")

# 3. Read the CSV from the file path, skipping the metadata
raw_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("skipRows", rows_to_skip) \
    .option("inferSchema", "true") \
    .load(file_path)

# 4. Save the correctly loaded data as our bronze table
print("Saving clean data to: mycatalog.default.wages_bronze")
raw_df.write.format("delta").mode("overwrite").saveAsTable("mycatalog.default.wages_bronze")

print("✅ Successfully created wages_bronze table.")

# 5. Display the new, clean table to confirm
display(spark.table("mycatalog.default.wages_bronze"))

# %% [markdown]
# ## Import the table and print the first 10 rows for inspecting the data

# %% [markdown]
# ##Cleaning the data

# %%
# %sql


SELECT COUNT(*) AS rows_cpi_silver
FROM mycatalog.default.cpi_silver;

# %%
# %sql
SELECT COUNT(*) AS rows_wages_silver
FROM mycatalog.default.wages_silver;

# %%
# %sql
SELECT * 
FROM mycatalog.default.wages_silver
LIMIT 5;

# %%
# %sql

SELECT * 
FROM mycatalog.default.cpi_silver
LIMIT 5;
